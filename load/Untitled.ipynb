# %%
import json
with open("logs.jsonl") as inf:
    logs = [json.loads(l) for l in inf]

# %%
len(logs)
# Out:
# 102

# %%
logs
# Out:
# [{'timestamp': '2024-12-06T23:31:28.329792Z',
#   'level': 'INFO',
#   'message': 'Transaction committed, commit took: 14ms total transaction time: 474',
#   'target': 'iceberg_catalog::implementations::postgres',
#   'filename': 'crates/iceberg-catalog/src/implementations/postgres/mod.rs',
#   'line_number': 108,
#   'span': {'name': 'commit_write_transaction'},
#   'spans': [{'method': 'POST',
#     'request_id': '01939e50-5f44-7353-8f79-4277735ef998',
#     'uri': '/catalog/v1/a89475d6-b426-11ef-a817-9bb0eaa896e9/namespaces/demo_namespace/tables/my_table_855',
#     'version': 'HTTP/1.1',
#     'name': 'request'},
#    {'name': 'commit_write_transaction'}]},
#  {'timestamp': '2024-12-06T23:31:28.328993Z',
#   'level': 'INFO',
#   'message': 'Transaction committed, commit took: 12ms total transaction time: 487',
#   'target': 'iceberg_catalog::implementations::postgres',
#   'filename': 'crates/iceberg-catalog/src/implementations/postgres/mod.rs',
#   'line_number': 108,
# ...

# %%
logs
# Out:
# [{'timestamp': '2024-12-06T23:31:28.329792Z',
#   'level': 'INFO',
#   'message': 'Transaction committed, commit took: 14ms total transaction time: 474',
#   'target': 'iceberg_catalog::implementations::postgres',
#   'filename': 'crates/iceberg-catalog/src/implementations/postgres/mod.rs',
#   'line_number': 108,
#   'span': {'name': 'commit_write_transaction'},
#   'spans': [{'method': 'POST',
#     'request_id': '01939e50-5f44-7353-8f79-4277735ef998',
#     'uri': '/catalog/v1/a89475d6-b426-11ef-a817-9bb0eaa896e9/namespaces/demo_namespace/tables/my_table_855',
#     'version': 'HTTP/1.1',
#     'name': 'request'},
#    {'name': 'commit_write_transaction'}]},
#  {'timestamp': '2024-12-06T23:31:28.328993Z',
#   'level': 'INFO',
#   'message': 'Transaction committed, commit took: 12ms total transaction time: 487',
#   'target': 'iceberg_catalog::implementations::postgres',
#   'filename': 'crates/iceberg-catalog/src/implementations/postgres/mod.rs',
#   'line_number': 108,
# ...
